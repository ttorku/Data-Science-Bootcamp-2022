# %% [markdown]
# ### Pandas

# %%
#packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(123)

# %% [markdown]
# ### Series

# %%
#create a series from
#list
#an array
#dictionary

# %%
#list
ml =[78, 85, 79, 90]
myser1 =pd.Series(ml)

# %%
myser1
# Out:
# 0    78
# 1    85
# 2    79
# 3    90
# dtype: int64

# %%
myind =['Stud_A', 'Stud_B', 'Stud_C', 'Stud_D']

# %%
myser1 =pd.Series(ml, myind)
myser1
# Out:
# Stud_A    78
# Stud_B    85
# Stud_C    79
# Stud_D    90
# dtype: int64

# %%
#array
myarr =np.random.randint(0,100, size=(4,))

# %%
myarr
# Out:
# array([66, 92, 98, 17])

# %%
myser2 =pd.Series(myarr)
myser2
# Out:
# 0    66
# 1    92
# 2    98
# 3    17
# dtype: int32

# %%
myser2 =pd.Series(myarr, myind)
myser2
# Out:
# Stud_A    66
# Stud_B    92
# Stud_C    98
# Stud_D    17
# dtype: int32

# %%
#dictionary
mydic ={'Stud_A':77, 'Stud_B': 98, 'Stud_C': 67, 'Stud_D':88}
myser3 =pd.Series(mydic)
myser3
# Out:
# Stud_A    77
# Stud_B    98
# Stud_C    67
# Stud_D    88
# dtype: int64

# %% [markdown]
# ### Basic Operations or Methods on Series

# %%
myser3.keys()
# Out:
# Index(['Stud_A', 'Stud_B', 'Stud_C', 'Stud_D'], dtype='object')

# %%
myser2.keys()
# Out:
# Index(['Stud_A', 'Stud_B', 'Stud_C', 'Stud_D'], dtype='object')

# %%
myser1.index
# Out:
# Index(['Stud_A', 'Stud_B', 'Stud_C', 'Stud_D'], dtype='object')

# %%
myser1 +myser2
# Out:
# Stud_A    144
# Stud_B    177
# Stud_C    177
# Stud_D    107
# dtype: int64

# %%
len(myser1)
# Out:
# 4

# %%
myser2.agg(['min', 'max'])
# Out:
# min    17
# max    98
# dtype: int64

# %%
# help(pd.Series)

# %% [markdown]
# ### DataFrame

# %%
##create a dataframe from an array
myarr1 =np.random.randint(0,100, size=(5,5))
col =['River', 'Oyo', 'Niger', 'Lagos', 'Delta']

df =pd.DataFrame(myarr1)

# %%
df
# Out:
#     0   1   2   3   4
# 0  26  80   6  14  75
# 1  54  71   1  43  58
# 2  55  25  50  84  56
# 3  49  12  18  81   1
# 4  51  44  48  56  91

# %%
ind =['Jan', 'Feb', 'Mar', 'Apr', 'May']

df =pd.DataFrame(myarr1, index=ind, columns=col)
df
# Out:
#      River  Oyo  Niger  Lagos  Delta
# Jan     26   80      6     14     75
# Feb     54   71      1     43     58
# Mar     55   25     50     84     56
# Apr     49   12     18     81      1
# May     51   44     48     56     91

# %%
myarrt =np.random.random((5,5))

# %%
myarrt
# Out:
# array([[0.58593655, 0.6249035 , 0.67468905, 0.84234244, 0.08319499],
#        [0.76368284, 0.24366637, 0.19422296, 0.57245696, 0.09571252],
#        [0.88532683, 0.62724897, 0.72341636, 0.01612921, 0.59443188],
#        [0.55678519, 0.15895964, 0.15307052, 0.69552953, 0.31876643],
#        [0.6919703 , 0.55438325, 0.38895057, 0.92513249, 0.84167   ]])

# %%
mydata =pd.read_csv("autos_mpg.csv")
mydata.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mydata.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin         car_name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
mydata.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
#Referencing a column
mydata['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
plt.plot(mydata['mpg'])

# %%
mydata['cylinders']
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 393    4
# 394    4
# 395    4
# 396    4
# 397    4
# Name: cylinders, Length: 398, dtype: int64

# %%
twodata=mydata[['mpg', 'cylinders']]

# %%
twodata
# Out:
#       mpg  cylinders
# 0    18.0          8
# 1    15.0          8
# 2    18.0          8
# 3    16.0          8
# 4    17.0          8
# ..    ...        ...
# 393  27.0          4
# 394  44.0          4
# 395  32.0          4
# 396  28.0          4
# 397  31.0          4
#
# [398 rows x 2 columns]

# %%
#adding a new column
mydata['is_overspeed'] =False

# %%
mydata
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name  is_overspeed
# 0            70       1  chevrolet chevelle malibu         False
# ...

# %%
mydata.drop(columns='is_overspeed', inplace=True, axis=1)

# %%
mydata
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
mydata.to_csv('mpg_updated.csv')

# %%
#groupby method
mydata.groupby('cylinders').count()
# Out:
#            mpg  displacement  horsepower  weight  acceleration  model_year  \
# cylinders
# 3            4             4           4       4             4           4
# 4          204           204         204     204           204         204
# 5            3             3           3       3             3           3
# 6           84            84          84      84            84          84
# 8          103           103         103     103           103         103
#
#            origin  car_name
# cylinders
# 3               4         4
# 4             204       204
# 5               3         3
# 6              84        84
# 8             103       103

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
arr1 =np.array([1.2, 3.4], dtype=np.float32)

# %%
arr1
# Out:
# array([1.2, 3.4], dtype=float32)

# %% [markdown]
# #Pandas Part 2

# %%
#read data with pandas 
#perform more interesting data science operations with pandas
#extract, one, multiple column
#add new column
#adjust column
#delete column

##Index
#set_index
#perform extraction through index
#reset_index

#sort by, two, multiple indexes. 
#extracting rows with iloc

#subsetting

#lambda functions

# %%
import pandas as pd
import numpy as np

# %%
attendance = pd.read_csv("church_attendance.csv")
attendance
# Out:
#     First Name Last Name Worker_Status  House Holde Number  Service attended
# 0       Daniel   Johnson        worker                   5                15
# 1    Blessing       Madu        worker                   3                20
# 2  Makanjuola   Adekunmi        worker                   2                14
# 3        John      James    Non worker                   6                21
# 4     Jeremiah  Akindele        worker                   7                25

# %%
#clean column names
columns = attendance.columns.to_list()
columns[0] = 'First_Name'
columns[1] = 'Last_Name'
columns[3] = 'House_Hold_Number'
columns[4] = 'Service_attended'
attendance.columns = columns
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# 0       Daniel   Johnson        worker                  5                15
# 1    Blessing       Madu        worker                  3                20
# 2  Makanjuola   Adekunmi        worker                  2                14
# 3        John      James    Non worker                  6                21
# 4     Jeremiah  Akindele        worker                  7                25

# %%
#Extracting columns
attendance['First_Name']
# Out:
# 0         Daniel
# 1      Blessing
# 2    Makanjuola
# 3          John
# 4       Jeremiah
# Name: First_Name, dtype: object

# %%
attendance[['First_Name', 'House_Hold_Number']]
# Out:
#     First_Name  House_Hold_Number
# 0       Daniel                  5
# 1    Blessing                   3
# 2  Makanjuola                   2
# 3        John                   6
# 4     Jeremiah                  7

# %%
gender = ["Male", "Female", "Male", "Male", "Male"]

# %%
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# 0       Daniel   Johnson        worker                  5                15
# 1    Blessing       Madu        worker                  3                20
# 2  Makanjuola   Adekunmi        worker                  2                14
# 3        John      James    Non worker                  6                21
# 4     Jeremiah  Akindele        worker                  7                25

# %%
attendance['Gender'] = gender
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                15
# 1    Blessing       Madu        worker                  3                20
# 2  Makanjuola   Adekunmi        worker                  2                14
# 3        John      James    Non worker                  6                21
# 4     Jeremiah  Akindele        worker                  7                25
#
#    Gender
# 0    Male
# 1  Female
# 2    Male
# 3    Male
# 4    Male

# %%
#Edit a column
#Add 4 to service attended
attendance['Service_attended'] = attendance['Service_attended'] + 4
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#    Gender
# 0    Male
# 1  Female
# 2    Male
# 3    Male
# 4    Male

# %%
attendance.iloc[2]['House_Hold_Number'] = 4
attendance
# Out:
#      ID   First_Name Last_Name Worker_Status  House_Hold_Number  \
# 0  1001       Daniel   Johnson        worker                  5
# 1  1024    Blessing       Madu        worker                  3
# 2  1035  Makanjuola   Adekunmi        worker                  2
# 3  1078        John      James    Non worker                  6
# 4  1986     Jeremiah  Akindele        worker                  7
#
#    Service_attended
# 0                19
# 1                24
# 2                18
# 3                25
# 4                29

# %%
#delete a column

attendance.pop("Gender")
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# Name: Gender, dtype: object

# %%
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29

# %%
#create a new dataframe of worker status and age
worker_status = attendance['Worker_Status']
age = [18,20,22,24,26]
new_df = pd.DataFrame({"Worker_status": worker_status, "Age" :age})
new_df
# Out:
#   Worker_status  Age
# 0        worker   18
# 1        worker   20
# 2        worker   22
# 3    Non worker   24
# 4        worker   26

# %% [markdown]
# ### Indexing

# %%
##Index
#set_index
#perform extraction through index
#reset_index

# %%
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29

# %%
attendance["ID"] = [1001, 1024, 1035, 1078, 1986]
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#      ID
# 0  1001
# 1  1024
# 2  1035
# 3  1078
# 4  1986

# %%
attendance.set_index("ID", inplace = True)

# %%
attendance
# Out:
#        First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# ID
# 1001       Daniel   Johnson        worker                  5                19
# 1024    Blessing       Madu        worker                  3                24
# 1035  Makanjuola   Adekunmi        worker                  2                18
# 1078        John      James    Non worker                  6                25
# 1986     Jeremiah  Akindele        worker                  7                29

# %%
attendance.loc[1001]
# Out:
# First_Name            Daniel
# Last_Name            Johnson
# Worker_Status         worker
# House_Hold_Number          5
# Service_attended          19
# Name: 1001, dtype: object

# %%
attendance.loc[1001]['First_Name']
# Out:
# 'Daniel'

# %%
attendance.loc[[1001, 1024]]
# Out:
#      First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# ID
# 1001     Daniel   Johnson        worker                  5                19
# 1024  Blessing       Madu        worker                  3                24

# %%
attendance
# Out:
#        First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# ID
# 1001       Daniel   Johnson        worker                  5                19
# 1024    Blessing       Madu        worker                  3                24
# 1035  Makanjuola   Adekunmi        worker                  2                18
# 1078        John      James    Non worker                  6                25
# 1986     Jeremiah  Akindele        worker                  7                29

# %%
attendance.reset_index()
# Out:
#      ID   First_Name Last_Name Worker_Status  House_Hold_Number  \
# 0  1001       Daniel   Johnson        worker                  5
# 1  1024    Blessing       Madu        worker                  3
# 2  1035  Makanjuola   Adekunmi        worker                  2
# 3  1078        John      James    Non worker                  6
# 4  1986     Jeremiah  Akindele        worker                  7
#
#    Service_attended
# 0                19
# 1                24
# 2                18
# 3                25
# 4                29

# %%
attendance.iloc[0:2]
# Out:
#      First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# ID
# 1001     Daniel   Johnson        worker                  5                19
# 1024  Blessing       Madu        worker                  3                24

# %%
attendance = attendance.reset_index()

# %%
#sort by, two, multiple indexes. 
#extracting rows with iloc

#sort by 1 column
attendance.sort_values("First_Name")
# Out:
#      ID   First_Name Last_Name Worker_Status  House_Hold_Number  \
# 1  1024    Blessing       Madu        worker                  3
# 0  1001       Daniel   Johnson        worker                  5
# 4  1986     Jeremiah  Akindele        worker                  7
# 3  1078        John      James    Non worker                  6
# 2  1035  Makanjuola   Adekunmi        worker                  2
#
#    Service_attended
# 1                24
# 0                19
# 4                29
# 3                25
# 2                18

# %%
attendance.sort_values(["Worker_Status", "House_Hold_Number"])
# Out:
#      ID   First_Name Last_Name Worker_Status  House_Hold_Number  \
# 3  1078        John      James    Non worker                  6
# 2  1035  Makanjuola   Adekunmi        worker                  2
# 1  1024    Blessing       Madu        worker                  3
# 0  1001       Daniel   Johnson        worker                  5
# 4  1986     Jeremiah  Akindele        worker                  7
#
#    Service_attended
# 3                25
# 2                18
# 1                24
# 0                19
# 4                29

# %%
attendance[['ID',
 'First_Name',
  'Service_attended',
 'Last_Name',
 'Worker_Status',
 'House_Hold_Number']]
# Out:
#      ID   First_Name  Service_attended Last_Name Worker_Status  \
# 0  1001       Daniel                19   Johnson        worker
# 1  1024    Blessing                 24      Madu        worker
# 2  1035  Makanjuola                 18  Adekunmi        worker
# 3  1078        John                 25     James    Non worker
# 4  1986     Jeremiah                29  Akindele        worker
#
#    House_Hold_Number
# 0                  5
# 1                  3
# 2                  2
# 3                  6
# 4                  7

# %%
attendance.columns.to_list()
# Out:
# ['ID',
#  'First_Name',
#  'Last_Name',
#  'Worker_Status',
#  'House_Hold_Number',
#  'Service_attended']
